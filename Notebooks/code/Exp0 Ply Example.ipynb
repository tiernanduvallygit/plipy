# %% [markdown]
# # Ply Example using Exp0

# %% [markdown]
# This notebook shows how to use the objects generated by Ply (lexer and parser) to do some actual parsing.

# %%
# import our Ply objects
from exp0_lex import lexer
from exp0_gram import parser
# Out:
# WARNING: Token 'NEWLINE' defined, but not used
# WARNING: There is 1 unused token

# %%
# do some parsing...
parser.parse("s x 1; s y + x 1;", lexer=lexer)
